# %%
import sys
import os

# 1. Get the path to the folder ABOVE 'notebooks'
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# 2. Add that folder to Python's search list
if project_root not in sys.path:
    sys.path.append(project_root)

# 3. Optional: Change the 'current directory' to the root
# This makes it so your code acts like it's running from the main project folder
os.chdir(project_root)

print(f"Project root added: {project_root}")
# Out:
# Project root added: c:\Users\Admin\Documents\StudyThingy\Projects\mldl_lib

# %%
import numpy as np
import pandas as pd
from ml_algorithms.supervised.linear_regression import LinearRegression
from ml_algorithms.supervised.logistic_regression import LogisticRegression
from utils.benchmark import Benchmarker
from utils.data_manipulation import train_test_split
from utils.data_operation import StandardScaler

# %%
df = pd.read_csv('data/synthetic_premium_dataset.csv')
